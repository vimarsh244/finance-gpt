# %%
# !pip install langchain
# !pip install openai
# !pip install pypdf
# !pip install faiss-cpu

import langchain
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !wget https://www.bseindia.com/bseplus/AnnualReport/500470/73142500470.pdf

# %%
import langchain
from langchain.document_loaders import PyPDFLoader
loader = PyPDFLoader("/content/73142500470.pdf")
pages = loader.load_and_split()
pages[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-cd211f6248b3> in <module>
#       1 import langchain
#       2 from langchain.document_loaders import PyPDFLoader
# ----> 3 loader = PyPDFLoader("/content/73142500470.pdf")
#       4 pages = loader.load_and_split()
#       5 pages[0]
#
# /usr/local/lib/python3.9/dist-packages/langchain/document_loaders/pdf.py in __init__(self, file_path)
#      89                 "pypdf package not found, please install it with " "`pip install pypdf`"
#      90             )
# ---> 91         super().__init__(file_path)
#      92
#      93     def load(self) -> List[Document]:
#
# /usr/local/lib/python3.9/dist-packages/langchain/document_loaders/pdf.py in __init__(self, file_path)
#      53             self.file_path = self.temp_file.name
#      54         elif not os.path.isfile(self.file_path):
# ...

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings.openai import OpenAIEmbeddings

faiss_index = FAISS.from_documents(pages, OpenAIEmbeddings())
faiss_index.save_local("/content/faiss_index")


docs = faiss_index.similarity_search("What are the current inventories", k=2)




# for doc in docs:
#     print(str(doc.metadata["page"]) + ":", doc.page_content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a9a754cb54f0> in <module>
#       2 from langchain.embeddings.openai import OpenAIEmbeddings
#       3
# ----> 4 faiss_index = FAISS.from_documents(pages, OpenAIEmbeddings())
#       5 faiss_index.save_local("/content/faiss_index")
#       6
#
# NameError: name 'pages' is not defined

# %%
query = "what are the current inventories"
from langchain.embeddings.openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings()

embedding_vector = embeddings.embed_query(query)

# %%
embedding_vector

# %%
str(embedding_vector)
# Out:
# '[-0.006759787909686565, -0.0009213292505592108, -0.01884056255221367, -0.009405561722815037, -0.03479616343975067, 0.002877601655200124, -0.050398506224155426, -0.007024733349680901, -0.015065090730786324, -0.010980515740811825, 0.01975315250456333, 0.0051627554930746555, -0.0052400315180420876, 0.018119322136044502, 0.00923629105091095, 0.021975750103592873, 0.020783495157957077, -0.007595101837068796, 0.002991675166413188, -0.04730747640132904, -0.0022041986230760813, 0.009891294874250889, -0.014984134584665298, -0.007046811748296022, 0.009464439004659653, -0.02227013371884823, 0.019885625690221786, -0.02465464174747467, -0.014873741194605827, -0.0032603004947304726, 0.0037791519425809383, -0.009295168332755566, -0.01794269122183323, -0.013975870795547962, -0.014527839608490467, -0.006954817101359367, 0.0012612505815923214, -0.019046630710363388, -0.01042118575423956, -0.016544368118047714, 0.017486397176980972, 0.036562465131282806, 1.1506554074003361e-05, 0.01129697822034359, -0
# ...

# %%
new_db = FAISS.load_local("/content/faiss_index", embeddings)

# %%
docs_and_scores = new_db.similarity_search_by_vector(embedding_vector)

# %%
docs_and_scores.page_content
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-1c613aaa6812> in <module>
# ----> 1 docs_and_scores.page_content
#
# AttributeError: 'list' object has no attribute 'page_content'

# %%
docs_and_scores[0].page_content
docs_and_scores[1].page_content
docs_and_scores[2].page_content
docs_and_scores[3].page_content
# Out:
# 'CONSOLIDATED BALANCE SHEET\nas at March 31, 2022\n (₹ crore) \nNote PageAs at  \nMarch 31, 2022 As at  \nMarch 31, 2021 \nAssets\nI Non-current assets\n(a) Property, plant and equipment 3 422  1,16,166.46  1,19,003.50 \n(b) Capital work-in-progress 3 426  21,227.62  18,128.74 \n(c) Right-of-use assets 4 428  8,337.70  9,450.95 \n(d) Goodwill on consolidation 5 431  4,311.20  4,344.69 \n(e) Other intangible assets 6 433  4,472.47  2,976.04 \n(f) Intangible assets under development 6 435  817.93  878.66 \n(g) Advance against equity  1,210.00  - \n(h) Equity accounted investments 7 436  2,961.65  2,475.66 \n(i) Financial assets\n(i) Investments 8 438  1,653.78  987.38 \n(ii) Loans 9 439  72.44  91.93 \n(iii) Derivative assets  318.15  162.66 \n(iv) Other financial assets 10 440  442.64  459.57 \n(j) Retirement benefit assets 11 441  20,397.96  20,019.47 \n(k) Non-current tax assets  3,785.01  1,845.34 \n(l) Deferred tax assets 12 442  3,023.93  1,578.02 \n(m) Other assets 13 445  3,690
# ...

# %%
len(docs_and_scores)
# Out:
# 4

# %%
#docs_and_scores[3]
# Out:
# Document(page_content='CONSOLIDATED BALANCE SHEET\nas at March 31, 2022\n (₹ crore) \nNote PageAs at  \nMarch 31, 2022 As at  \nMarch 31, 2021 \nAssets\nI Non-current assets\n(a) Property, plant and equipment 3 422  1,16,166.46  1,19,003.50 \n(b) Capital work-in-progress 3 426  21,227.62  18,128.74 \n(c) Right-of-use assets 4 428  8,337.70  9,450.95 \n(d) Goodwill on consolidation 5 431  4,311.20  4,344.69 \n(e) Other intangible assets 6 433  4,472.47  2,976.04 \n(f) Intangible assets under development 6 435  817.93  878.66 \n(g) Advance against equity  1,210.00  - \n(h) Equity accounted investments 7 436  2,961.65  2,475.66 \n(i) Financial assets\n(i) Investments 8 438  1,653.78  987.38 \n(ii) Loans 9 439  72.44  91.93 \n(iii) Derivative assets  318.15  162.66 \n(iv) Other financial assets 10 440  442.64  459.57 \n(j) Retirement benefit assets 11 441  20,397.96  20,019.47 \n(k) Non-current tax assets  3,785.01  1,845.34 \n(l) Deferred tax assets 12 442  3,023.93  1,578.02 \n(m) Othe
# ...
